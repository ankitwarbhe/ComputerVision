# %% [markdown]
# ### Import Libraries

# %% [markdown]
# ### Open Image

# %% [markdown]
# ### Convert Image

# %% [markdown]
# ### Display it

# %% [markdown]
# ### Create Classifier

# %% [markdown]
# ### It's a Kind of Magic

# %% [markdown]
# ### Check the Results
